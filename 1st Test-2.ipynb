# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>MIKE DELIS</b>
#
# Enterpreneur

# %% [markdown]
# <i>I'm intrested in data science because i want to learn how to extract data and use them to create machine learning models.</i>

# %% [markdown]
# ##My code will asign a number to a variable and then it will calculate and print the sum of this variable with another number.

# %%
a = 1
y = 1 + a
print (y)
# Out:
# 2

# %% [markdown]
# ![960x0.jpg](attachment:960x0.jpg)
# www.fithabits.gr
# *
# *
